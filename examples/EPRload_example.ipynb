# %%
from eprload import eprload
from pathlib import Path
from pprint import pp
from matplotlib import pyplot as plt

# get all implemented text files from eprfiles
implExt = ['*.dsc','*.dta','*.DSC','*.DTA']#, '*.d01','.exp'] # implemented file extensions
srchPath = Path('./eprfiles/')
impFiles = [] 
for ext in implExt:
	impFiles = impFiles + list(srchPath.rglob(ext))
# impFiles

# %%
testspec = eprload(impFiles[1])
# tso = testspec.esfmt
# pp(testspec.Absc)
# pp(testspec.Spec)
# pp(testspec.Param)
# print(testspec.Param)

# %%
plt.plot(testspec.Absc,testspec.Spec)
plt.xlabel('B (G)')
plt.ylabel("Intensity")
# Out:
# Text(0, 0.5, 'Intensity')
